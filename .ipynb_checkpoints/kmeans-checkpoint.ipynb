# %%
import scipy.io as spio
import matplotlib.pyplot as plt
import numpy as np
import random
from scipy import sparse
from sklearn.cluster import KMeans
import online_dictionary_learning.omp as omp

# %%
IP_data_mat=spio.loadmat("data/IP/Indian_pines_corrected.mat")
IP_gt_mat=spio.loadmat("data/IP/Indian_pines_gt.mat")
IP_image=IP_data_mat["indian_pines_corrected"]
IP_gt=IP_gt_mat['indian_pines_gt']

pavia_mat = spio.loadmat('data/PaviaU/PaviaU.mat')
pavia_gt_mat = spio.loadmat('data/PaviaU/PaviaU_gt.mat')
pavia_image = pavia_mat['paviaU']
pavia_gt = pavia_gt_mat['paviaU_gt']

salinas_mat = spio.loadmat('data/Salinas/salinas.mat')
salinas_gt_mat = spio.loadmat('data/Salinas/salinas_gt.mat')
salinas_image = salinas_mat['salinasA_corrected']
salinas_gt = salinas_gt_mat['salinasA_gt']

IP_dictionary = np.load('results/440_5_10000_dictionary.npy')
salinas_dictionary = np.load('results/440_5_10000_salinas.npy')
pavia_dictionary = np.load('results/260_3_10000_pavia.npy')

# %%
IP_flat = np.reshape(IP_image, (-1, 200))
IP_gt_flat = np.reshape(IP_gt, (-1))
IP_flat = IP_flat[IP_gt_flat!=0]
kmeans = KMeans(n_clusters=16, random_state=0).fit(IP_flat)

print(np.max(IP_gt))
print(np.max(pavia_gt))
print(np.max(salinas_gt))
print(IP_gt_flat.shape[0])
# Out:
# 16
# 9
# 14
# 21025

# %%
coefs = np.zeros((IP_flat.shape[0], IP_dictionary.shape[1]))
for i in range(coefs.shape[0]):
    coefs[i]=omp.omp(IP_dictionary, IP_flat[i], L=5, eps=None)
    if i+1<IP_flat.shape[0]:
        print('[' + str(i+1) + '] ' + str(np.round(((i+1)/IP_flat.shape[0])*100,2)) + '%', end='\r')
    else:
        print('[' + str(i+1) + '] ' + str(np.round(((i+1)/IP_flat.shape[0])*100,2)) + '%', end='\n')
kmeans_sparse = KMeans(n_clusters=16, random_state=0).fit(coefs)
# Out:
# [10249] 100.0%

# %%
labels = kmeans.labels_
labels_sparse = kmeans_sparse.labels_

# %%
count = 0
loc = 0
final = np.zeros(21025)
final_sparse = np.zeros(21025)
while(count<labels.shape[0]):
    if (IP_gt_flat[loc]!=0):
        final[loc]=labels[count]+1
        final_sparse[loc]=labels_sparse[count]+1
        count+=1
    loc+=1
final=np.reshape(final, (145,145))
final_sparse=np.reshape(final_sparse, (145,145))
print(np.max(labels))
# Out:
# 15

# %%
f, ax = plt.subplots(1,3, figsize=(15,15))
ax[0].title.set_text('Ground Truth')
ax[0].imshow(IP_gt)
ax[1].title.set_text('Standard Clustering')
ax[1].imshow(final)
ax[2].title.set_text('Sparse Clustering')
ax[2].imshow(final_sparse)
plt.show()

# %%
def kmeans_compare(image, gt, dictionary, verbose=False):
    # Original shape of image
    original_shape = gt.shape
    # flatten image and gt data
    image_flat = np.reshape(image, (-1, image.shape[2]))
    gt_flat = np.reshape(gt, (-1))
    # Remove Misc. Data
    image_flat = image_flat[gt_flat!=0]
    
    # Compute Sparse Coefficients
    coefs = np.zeros((image_flat.shape[0], dictionary.shape[1]))
    
    if verbose:
        print('Computing sparse coefficients:\n')
    
    for i in range(coefs.shape[0]):
        coefs[i]=omp.omp(dictionary, image_flat[i], L=5, eps=None)
        if verbose:
            if i+1<image_flat.shape[0]:
                print('[' + str(i+1) + '] ' + str(np.round(((i+1)/image_flat.shape[0])*100,2)) + '%', end='\r')
            else:
                print('[' + str(i+1) + '] ' + str(np.round(((i+1)/image_flat.shape[0])*100,2)) + '%', end='\n')

    # Run K-Means for both data sets
    k = np.max(gt_flat)
    kmeans_o = KMeans(n_clusters=k, random_state=0).fit(image_flat)
    kmeans_s = KMeans(n_clusters=k, random_state=0).fit(coefs)
    
    # Get labels
    labels_o = kmeans_o.labels_
    labels_s = kmeans_s.labels_
    
    # Reconstruct Images
    
    count, loc, n = 0, 0, gt_flat.shape[0]
    final_o, final_s = np.zeros(n), np.zeros(n)
    while count<labels_o.shape[0]:
        if (gt_flat[loc]!=0):
            final_o[loc]=labels_o[count]+1
            final_s[loc]=labels_s[count]+1
            count+=1
        loc+=1
    

    # Reshape
    final_o, final_s = np.reshape(final_o, original_shape), np.reshape(final_s, original_shape)
    
    # Return
    return [final_o, final_s]

# %%
check = kmeans_compare(pavia_image, pavia_gt, pavia_dictionary, verbose=True)
# Out:
# Computing sparse coefficients:
#
# [13104] 30.63%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-933b91078e9c> in <module>
# ----> 1 check = kmeans_compare(pavia_image, pavia_gt, pavia_dictionary, verbose=True)
#
# <ipython-input-21-a4a1bcaed81b> in kmeans_compare(image, gt, dictionary, verbose)
#      15
#      16     for i in range(coefs.shape[0]):
# ---> 17         coefs[i]=omp.omp(dictionary, image_flat[i], L=5, eps=None)
#      18         if verbose:
#      19             if i+1<image_flat.shape[0]:
#
# ~/Desktop/honours/hsi_ucdl/Project_code/online_dictionary_learning/omp.py in omp(D, x, L, eps)
#      42                 lam = np.abs(np.dot(residual, D)).argmax()
#      43                 idx.append(lam)
# ---> 44                 gamma, _, _, _ = linalg.lstsq(D[:, idx], x, rcond=None)
#      45                 residual = x - np.dot(D[:, idx], gamma)
#      46         alpha = np.zeros(D.shape[1])
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2154     signature = 'DDd->Ddid' if isComplexType(t) else 'ddd->ddid'
#    2155     extobj = get_linalg_error_extobj(_raise_linalgerror_lstsq)
# -> 2156     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2157
#    2158     # remove the axis we added
#
# KeyboardInterrupt:

# %%
plt.imshow(pavia_gt)
plt.show()
plt.imshow(check[0])
plt.show()
plt.imshow(check[1])
plt.show()
